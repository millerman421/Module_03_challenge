# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path as p #adding short-cut to work with to avoid coding path instead of Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bitstamp_dataframe = pd.read_csv (
    p("../Starter_Code/Resources/bitstamp.csv"), 
    index_col = "Timestamp",
    parse_dates=True,
    infer_datetime_format=True)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(bitstamp_dataframe.head(5))
display(bitstamp_dataframe.tail(5))
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# ...

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase_dataframe = pd.read_csv (
    p("../Starter_Code/Resources/coinbase.csv"), 
    index_col = "Timestamp",
    parse_dates=True,
    infer_datetime_format=True)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(coinbase_dataframe.head(5))
display(coinbase_dataframe.tail(5))
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
#before
display(bitstamp_dataframe.isnull().sum())
display(bitstamp_dataframe.isnull().mean())

#after
bitstamp_dataframe = bitstamp_dataframe.dropna()
display(bitstamp_dataframe.isnull().sum())
# Out:
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64
# Open              0.003651
# High              0.003651
# Low               0.003651
# Close             0.000000
# BTC Volume        0.003651
# USD Volume        0.003651
# Weighted Price    0.003651
# dtype: float64
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
bitstamp_dataframe.loc[:,"Close"] = bitstamp_dataframe.loc[:,"Close"].str.replace("$","")
display(bitstamp_dataframe.head(25))
# Out:
# <ipython-input-457-d1c4a07f7ddb>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bitstamp_dataframe.loc[:,"Close"] = bitstamp_dataframe.loc[:,"Close"].str.replace("$","")
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
# 2018-01-01 00:05:00  13620.00  13634.15  13610.00   13610.0    4.716162
# 2018-01-01 00:06:00  13610.00  13650.18  13590.42  13600.56   26.432759
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
#before
display(bitstamp_dataframe.dtypes)

#after
bitstamp_dataframe.loc[:,"Close"] = bitstamp_dataframe.loc[:,"Close"].astype("float")
display(bitstamp_dataframe.head(25))
display(bitstamp_dataframe.dtypes)
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00  13620.00    1.069665
# 2018-01-01 00:05:00  13620.00  13634.15  13610.00  13610.00    4.716162
# 2018-01-01 00:06:00  13610.00  13650.18  13590.42  13600.56   26.432759
# 2018-01-01 00:07:00  13593.99  13595.41  13566.93  13580.00   10.674241
# 2018-01-01 00:08:00  13580.00  13580.00  13547.59  13579.00   19.322370
# ...

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
display(bitstamp_dataframe.duplicated().sum())
display(bitstamp_dataframe.duplicated().mean())
# Out:
# 0
# 0.0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame

# Step 1 replace or drop all NaNs or missing values in the DataFrame
print("Step #1 \n\n\n ------------------")
#before
display(coinbase_dataframe.isnull().sum())
display(coinbase_dataframe.isnull().mean())

#after
coinbase_dataframe = coinbase_dataframe.dropna()
display(coinbase_dataframe.isnull().sum())

print("\n\n\nStep #2 \n\n\n ------------------")
# Step 2 Use the str.replace function to remove the dollar sign, $
display(coinbase_dataframe["Close"].dtypes)
coinbase_dataframe.loc[:,"Close"] = coinbase_dataframe.loc[:,"Close"].astype("str")
coinbase_dataframe.loc[:,"Close"] = coinbase_dataframe.loc[:,"Close"].str.replace("$","")
display(coinbase_dataframe.head(25))

print("\n\n\nStep #3 \n\n\n ------------------")
# Step 3 Convert the Close data type to a float
#before
display(coinbase_dataframe.dtypes)

#after
coinbase_dataframe.loc[:,"Close"] = coinbase_dataframe.loc[:,"Close"].astype("float")
display(coinbase_dataframe.head(25))
display(coinbase_dataframe.dtypes)

print("\n\n\nStep #4 \n\n\n ------------------")
# Step 4 Review the data for duplicate values, and drop them if necessary
display(coinbase_dataframe.duplicated().sum())
display(coinbase_dataframe.duplicated().mean())
# Out:
# Step #1
#
#
#  ------------------
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64
# Open              0.001683
# High              0.001683
# Low               0.001683
# Close             0.000000
# BTC Volume        0.001683
# USD Volume        0.001683
# Weighted Price    0.001683
# dtype: float64
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64
# Step #2
#
#
#  ------------------
# dtype('O')
# <ipython-input-460-9b7001d6228b>:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   coinbase_dataframe.loc[:,"Close"] = coinbase_dataframe.loc[:,"Close"].str.replace("$","")
# ...

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp_dataframe.loc[:,"Close"]
bitstamp_sliced.rename("Close_Bitstamp", inplace=True)

# Review the first five rows of the DataFrame
display(bitstamp_sliced.head(5))
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close_Bitstamp, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase_dataframe.loc[:,"Close"]
coinbase_sliced.rename("Close_Coinbase", inplace=True)
# Review the first five rows of the DataFrame
display(coinbase_sliced.head(5))
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close_Coinbase, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
display(bitstamp_sliced.describe())
display(bitstamp_sliced.skew())
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close_Bitstamp, dtype: float64
# 0.8016700301860757

# %%
# Generate the summary statistics for the coinbase DataFrame
display(coinbase_sliced.describe())
display(coinbase_sliced.skew())

#Practicing joining the data sets into a single dataframe
combined_bitcoin = pd.concat([bitstamp_sliced,coinbase_sliced],axis=1, join="outer")
combined_bitcoin.columns = ["Close_bitstamp","Close_coinbase"]
display(combined_bitcoin)
display(combined_bitcoin.describe())
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close_Coinbase, dtype: float64
# 0.8148976806206876
#                      Close_bitstamp  Close_coinbase
# Timestamp
# 2018-01-01 00:00:00        13646.48        13608.49
# 2018-01-01 00:01:00        13658.75        13601.66
# 2018-01-01 00:02:00        13610.22        13580.00
# 2018-01-01 00:03:00        13639.09        13550.34
# 2018-01-01 00:04:00        13620.00        13583.44
# ...                             ...             ...
# 2018-03-31 23:55:00         6922.56         6930.00
# 2018-03-31 23:56:00         6920.32         6930.01
# 2018-03-31 23:57:00         6934.72         6933.91
# 2018-03-31 23:58:00         6927.65         6937.31
# 2018-03-31 23:59:00         6928.01         6934.00
#
# [129537 rows x 2 columns]
#        Close_bitstamp  Close_coinbase
# ...

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
bitstamp_sliced.plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices",color="blue", legend=True)
# Out:
# <AxesSubplot:title={'center':'Bitstamp Prices'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase_sliced.plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Coinbase Prices",color="red", legend=True)
# Out:
# <AxesSubplot:title={'center':'Coinbase Prices'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and labe

#Method #1 overlay chart
bitstamp_sliced.plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Mathod #2 dataframes joined. #Practicing joining the data sets into a single dataframe
combined_bitcoin.plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
#Method #1 overlay chart
bitstamp_sliced.loc["2018-01-01":"2018-01-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.loc["2018-01-01":"2018-01-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Method #2 dataframes joined as a single data set. #Practicing joining the data sets into a single dataframe
combined_bitcoin.loc["2018-01-01":"2018-01-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 

#Method #1 overlay chart
bitstamp_sliced.loc["2018-03-01":"2018-03-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.loc["2018-03-01":"2018-03-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Method #2 dataframes joined as a single data set. #Practicing joining the data sets into a single dataframe
combined_bitcoin.loc["2018-03-01":"2018-03-31"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** The degree of spread has changed, but it has narrowed since January to a smaller spread during March.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 


#Method #1 overlay chart
bitstamp_sliced.loc["2018-01-28"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.loc["2018-01-28"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Method #2 dataframes joined as a single data set. #Practicing joining the data sets into a single dataframe
combined_bitcoin.loc["2018-01-28"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices



arbitrage_spread_early_1 = bitstamp_sliced.loc["2018-01-28"] - coinbase_sliced.loc["2018-01-28"]
display(arbitrage_spread_early_1)

#Practicing joining the data sets into a single dataframe
arbitrage_spread_early_2 = combined_bitcoin["Close_bitstamp"].loc["2018-01-28"] - combined_bitcoin["Close_coinbase"].loc["2018-01-28"]
display(arbitrage_spread_early_2)

# Generate summary statistics for the early DataFrame
display(arbitrage_spread_early_1.describe())

#Practicing joining the data sets into a single dataframe
display(arbitrage_spread_early_2.describe())
# Out:
# Timestamp
# 2018-01-28 00:00:00    275.38
# 2018-01-28 00:01:00    275.00
# 2018-01-28 00:02:00    268.77
# 2018-01-28 00:03:00    275.03
# 2018-01-28 00:04:00    294.26
#                         ...
# 2018-01-28 23:55:00    220.10
# 2018-01-28 23:56:00    195.11
# 2018-01-28 23:57:00    208.74
# 2018-01-28 23:58:00    195.12
# 2018-01-28 23:59:00    192.63
# Length: 1440, dtype: float64
# Timestamp
# 2018-01-28 00:00:00    275.38
# 2018-01-28 00:01:00    275.00
# 2018-01-28 00:02:00    268.77
# 2018-01-28 00:03:00    275.03
# 2018-01-28 00:04:00    294.26
#                         ...
# 2018-01-28 23:55:00    220.10
# 2018-01-28 23:56:00    195.11
# 2018-01-28 23:57:00    208.74
# 2018-01-28 23:58:00    195.12
# 2018-01-28 23:59:00    192.63
# Length: 1440, dtype: float64
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# dtype: float64
# ...

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
#Method #1 box chart
arbitrage_spread_early_1.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Early Date [2018-01-28]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Early Date [2018-01-28]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
#Method #2 box chart
#Practicing joining the data sets into a single dataframe
arbitrage_spread_early_2.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Early Date [2018-01-28]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Early Date [2018-01-28]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
#Method #1 overlay chart
bitstamp_sliced.loc["2018-02-15"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.loc["2018-02-15"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Method #2 dataframes joined as a single data set. #Practicing joining the data sets into a single dataframe
combined_bitcoin.loc["2018-02-15"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle_1 = bitstamp_sliced.loc["2018-02-15"] - coinbase_sliced.loc["2018-02-15"]
display(arbitrage_spread_middle_1)

#Practicing joining the data sets into a single dataframe
arbitrage_spread_middle_2 = combined_bitcoin["Close_bitstamp"].loc["2018-02-15"] - combined_bitcoin["Close_coinbase"].loc["2018-02-15"]
display(arbitrage_spread_middle_2)

# Generate summary statistics for the early DataFrame. #Practicing joining the data sets into a single dataframe
display(arbitrage_spread_middle_1.describe())
display(arbitrage_spread_middle_2.describe())
# Out:
# Timestamp
# 2018-02-15 00:00:00   -21.30
# 2018-02-15 00:01:00    -6.73
# 2018-02-15 00:02:00    -9.64
# 2018-02-15 00:03:00   -21.18
# 2018-02-15 00:04:00    -7.19
#                        ...
# 2018-02-15 23:55:00    15.48
# 2018-02-15 23:56:00    27.04
# 2018-02-15 23:57:00    44.32
# 2018-02-15 23:58:00    28.36
# 2018-02-15 23:59:00     3.00
# Length: 1440, dtype: float64
# Timestamp
# 2018-02-15 00:00:00   -21.30
# 2018-02-15 00:01:00    -6.73
# 2018-02-15 00:02:00    -9.64
# 2018-02-15 00:03:00   -21.18
# 2018-02-15 00:04:00    -7.19
#                        ...
# 2018-02-15 23:55:00    15.48
# 2018-02-15 23:56:00    27.04
# 2018-02-15 23:57:00    44.32
# 2018-02-15 23:58:00    28.36
# 2018-02-15 23:59:00     3.00
# Length: 1440, dtype: float64
# count    1440.000000
# mean        5.760007
# std        14.908671
# min       -48.800000
# 25%        -3.995000
# 50%         6.960000
# 75%        16.217500
# max        55.470000
# dtype: float64
# count    1440.000000
# ...

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
#Method #1 box chart
arbitrage_spread_middle_1.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Middle Date [2018-02-15]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Middle Date [2018-02-15]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
#Method #2 box chart. #Practicing joining the data sets into a single dataframe
arbitrage_spread_middle_2.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Middle Date [2018-02-15]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Middle Date [2018-02-15]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
#Method #1 overlay chart
bitstamp_sliced.loc["2018-03-25"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Bitstamp Prices vs Coinbase Prices",color="blue", legend=True)
coinbase_sliced.loc["2018-03-25"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),color="red",legend=True)

#Method #2 dataframes joined as a single data set. #Practicing joining the data sets into a single dataframe
combined_bitcoin.loc["2018-03-25"].plot(xlabel="Time Stamp", ylabel="Close Price",figsize=(10,5),title="Combined Prices - Bitstamp vs Coinbase",color=["blue","red"], legend=True)
# Out:
# <AxesSubplot:title={'center':'Combined Prices - Bitstamp vs Coinbase'}, xlabel='Time Stamp', ylabel='Close Price'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late_1 = bitstamp_sliced.loc["2018-03-25"] - coinbase_sliced.loc["2018-03-25"]
display(arbitrage_spread_late_1)

#Practicing joining the data sets into a single dataframe
arbitrage_spread_late_2 = combined_bitcoin["Close_bitstamp"].loc["2018-03-25"] - combined_bitcoin["Close_coinbase"].loc["2018-03-25"]
display(arbitrage_spread_late_2)

# Generate summary statistics for the early DataFrame
display(arbitrage_spread_late_1.describe())

#Practicing joining the data sets into a single dataframe
display(arbitrage_spread_late_2.describe())
# Out:
# Timestamp
# 2018-03-25 00:00:00     3.67
# 2018-03-25 00:01:00    -6.01
# 2018-03-25 00:02:00    -9.67
# 2018-03-25 00:03:00     7.51
# 2018-03-25 00:04:00     3.36
#                        ...
# 2018-03-25 23:55:00     0.82
# 2018-03-25 23:56:00     1.29
# 2018-03-25 23:57:00    -8.44
# 2018-03-25 23:58:00   -11.98
# 2018-03-25 23:59:00    -3.79
# Length: 1440, dtype: float64
# Timestamp
# 2018-03-25 00:00:00     3.67
# 2018-03-25 00:01:00    -6.01
# 2018-03-25 00:02:00    -9.67
# 2018-03-25 00:03:00     7.51
# 2018-03-25 00:04:00     3.36
#                        ...
# 2018-03-25 23:55:00     0.82
# 2018-03-25 23:56:00     1.29
# 2018-03-25 23:57:00    -8.44
# 2018-03-25 23:58:00   -11.98
# 2018-03-25 23:59:00    -3.79
# Length: 1440, dtype: float64
# count    1404.000000
# mean        2.294423
# std         9.853020
# min       -53.940000
# 25%        -3.767500
# 50%         2.805000
# 75%         8.810000
# max        34.640000
# dtype: float64
# count    1404.000000
# ...

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
#Method #1 box chart
arbitrage_spread_late_1.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Late Date [2018-03-25]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Late Date [2018-03-25]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
#Method #2 box chart
#Practicing joining the data sets into a single dataframe
arbitrage_spread_late_2.plot(label="Close", ylabel="Spread - Bitstamp vs Coinbase",kind="box",figsize=(10,5),title="Arbitrage Spread - Late Date [2018-03-25]")
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Late Date [2018-03-25]'}, ylabel='Spread - Bitstamp vs Coinbase'>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
"""Please note that the instructions already had the spread calculated in the previous steps, and out of the 3-dates selected 
because the average spread was a positive value based on Bitstamp minus Coinbase, the math is already completed for this first step. 
However, if for one of the selected dates, the average was negative, than the arbitrage opportunity would have reversed and I would have made the 
appropiate adjustment to only seek arbitrage for a positive average spreads
"""
display(arbitrage_spread_early_1.count())
display(arbitrage_spread_middle_1.count())
display(arbitrage_spread_late_1.count())
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_early_1_positive = arbitrage_spread_early_1[arbitrage_spread_early_1 > 0.0]
print(arbitrage_spread_early_1_positive.describe())

arbitrage_spread_middle_1_positive = arbitrage_spread_middle_1[arbitrage_spread_middle_1 > 0.0]
print(arbitrage_spread_middle_1_positive.describe())

arbitrage_spread_late_1_positive = arbitrage_spread_late_1[arbitrage_spread_late_1 > 0.0]
print(arbitrage_spread_late_1_positive.describe())
# Out:
# 1436
# 1440
# 1404
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# dtype: float64
# count    970.000000
# mean      13.963979
# std        9.337793
# min        0.010000
# 25%        6.715000
# 50%       12.735000
# 75%       19.667500
# max       55.470000
# dtype: float64
# count    862.000000
# mean       8.345858
# std        5.854515
# min        0.030000
# 25%        3.857500
# 50%        7.325000
# 75%       11.870000
# max       34.640000
# dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early_1 = arbitrage_spread_early_1_positive / coinbase_sliced.loc["2018-01-28"]
display(spread_return_early_1.head())
spread_return_early_1.isnull().sum()
spread_return_early_1.dropna()

spread_return_middle_1 = arbitrage_spread_middle_1_positive / coinbase_sliced.loc["2018-02-15"]
display(spread_return_middle_1.head())
spread_return_middle_1.isnull().sum()
spread_return_middle_1.dropna()

spread_return_late_1 = arbitrage_spread_late_1_positive / coinbase_sliced.loc["2018-03-25"]
display(spread_return_late_1.head())
spread_return_late_1.isnull().sum()
spread_return_late_1.dropna()

display(spread_return_early_1.count())
display(spread_return_middle_1.count())
display(spread_return_late_1.count())

display(spread_return_early_1.describe())
display(spread_return_middle_1.describe())
display(spread_return_late_1.describe())
# Out:
# Timestamp
# 2018-01-28 00:00:00    0.023999
# 2018-01-28 00:01:00    0.023965
# 2018-01-28 00:02:00    0.023392
# 2018-01-28 00:03:00    0.023936
# 2018-01-28 00:04:00    0.025610
# dtype: float64
# Timestamp
# 2018-02-15 00:00:00   NaN
# 2018-02-15 00:01:00   NaN
# 2018-02-15 00:02:00   NaN
# 2018-02-15 00:03:00   NaN
# 2018-02-15 00:04:00   NaN
# dtype: float64
# Timestamp
# 2018-03-25 00:00:00    0.000429
# 2018-03-25 00:01:00         NaN
# 2018-03-25 00:02:00         NaN
# 2018-03-25 00:03:00    0.000880
# 2018-03-25 00:04:00    0.000394
# dtype: float64
# 1436
# 970
# 862
# count    1436.000000
# mean        0.021648
# std         0.005961
# min         0.004885
# 25%         0.018369
# 50%         0.021897
# 75%         0.025292
# max         0.038510
# dtype: float64
# count    9.700000e+02
# mean     1.405761e-03
# std      9.403256e-04
# min      9.921639e-07
# 25%      6.771987e-04
# 50%      1.289004e-03
# 75%      1.966134e-03
# max      5.583848e-03
# dtype: float64
# ...

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early_1[spread_return_early_1>0.01]
profitable_trades_middle = spread_return_middle_1[spread_return_middle_1>0.01]
profitable_trades_late = spread_return_late_1[spread_return_late_1>0.01]

# Review the first five profitable trades
"""
No results captured for middle and late because trading costs turn the arbitrage negative
"""
display(profitable_trades_early.head(5))
display(profitable_trades_middle.head(5))
display(profitable_trades_late.head(5))
# Out:
# Timestamp
# 2018-01-28 00:00:00    0.023999
# 2018-01-28 00:01:00    0.023965
# 2018-01-28 00:02:00    0.023392
# 2018-01-28 00:03:00    0.023936
# 2018-01-28 00:04:00    0.025610
# dtype: float64
# Series([], dtype: float64)
# Series([], dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
display(profitable_trades_early.describe())
display(profitable_trades_middle.describe())
display(profitable_trades_late.describe())

"""Based on the dataframe and the summary statistics, only the early day trades were sufficient to cover the 1% of trading costs. The other two profit percentage was not enough to cover the 
trading costs of buying and selling. 
"""
# Out:
# count    1378.000000
# mean        0.022201
# std         0.005421
# min         0.010087
# 25%         0.019016
# 50%         0.022191
# 75%         0.025413
# max         0.038510
# dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# dtype: float64
# 'Based on the dataframe and the summary statistics, only the early day trades were sufficient to cover the 1% of trading costs. The other two profit percentage was not enough to cover the \ntrading costs of buying and selling. \n'

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

"""Because middle and early did nto cover trading costs the result is no profitable trades
as demonstrated below

"""

profit_early = coinbase_sliced.loc["2018-01-28"] * (profitable_trades_early-0.01)

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()

# View the early profit DataFrame
display(profit_per_trade_early)


profit_middle = coinbase_sliced.loc["2018-02-15"] * (profitable_trades_middle-0.01)

# Drop any missing values from the profit DataFrame
profit_per_trade_middle = profit_middle.dropna()

# View the early profit DataFrame
display(profit_per_trade_middle)


profit_late = coinbase_sliced.loc["2018-03-25"] * (profitable_trades_late-0.01)

# Drop any missing values from the profit DataFrame
profit_per_trade_late = profit_late.dropna()

# View the early profit DataFrame
display(profit_per_trade_late)
# Out:
# Timestamp
# 2018-01-28 00:00:00    160.6338
# 2018-01-28 00:01:00    160.2500
# 2018-01-28 00:02:00    153.8701
# 2018-01-28 00:03:00    160.1301
# 2018-01-28 00:04:00    179.3602
#                          ...
# 2018-01-28 23:55:00    107.3302
# 2018-01-28 23:56:00     82.3402
# 2018-01-28 23:57:00     95.9702
# 2018-01-28 23:58:00     82.3502
# 2018-01-28 23:59:00     79.9400
# Length: 1378, dtype: float64
# Series([], dtype: float64)
# Series([], dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
display(profit_per_trade_early.describe())

display(profit_per_trade_middle.describe())

display(profit_per_trade_late.describe())
# Out:
# count    1378.000000
# mean      139.586715
# std        61.887387
# min         0.990000
# 25%       103.367650
# 50%       139.219950
# 75%       177.627500
# max       325.010100
# dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early.plot(xlabel="Time Stamp", ylabel="Profit per Trade",figsize=(10,5),title="Profit per trade early day - 2018-01*28",color=["blue"])

profit_per_trade_middle.plot(xlabel="Time Stamp", ylabel="Profit per Trade",figsize=(10,5),title="Profit per trade early day - 2018-01*28",color=["blue"])

profit_per_trade_late.plot(xlabel="Time Stamp", ylabel="Profit per Trade",figsize=(10,5),title="Profit per trade early day - 2018-01*28",color=["blue"])
# Out:
# <AxesSubplot:title={'center':'Profit per trade early day - 2018-01*28'}, xlabel='Time Stamp', ylabel='Profit per Trade'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
display(profit_per_trade_early.sum())

display(profit_per_trade_middle.sum())

display(profit_per_trade_late.sum())
# Out:
# 192350.4936000001
# 0.0
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
display(profit_per_trade_early.cumsum())
display(profit_per_trade_middle.cumsum())
display(profit_per_trade_late.cumsum())
# Out:
# Timestamp
# 2018-01-28 00:00:00       160.6338
# 2018-01-28 00:01:00       320.8838
# 2018-01-28 00:02:00       474.7539
# 2018-01-28 00:03:00       634.8840
# 2018-01-28 00:04:00       814.2442
#                           ...
# 2018-01-28 23:55:00    192009.8930
# 2018-01-28 23:56:00    192092.2332
# 2018-01-28 23:57:00    192188.2034
# 2018-01-28 23:58:00    192270.5536
# 2018-01-28 23:59:00    192350.4936
# Length: 1378, dtype: float64
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
profit_per_trade_early.cumsum().plot(xlabel="Time Stamp", ylabel="Cummulative Profit by Time",figsize=(10,5),title="Cummulative Total Profit - 2018-01*28",color=["blue"])
profit_per_trade_middle.cumsum().plot()
profit_per_trade_late.cumsum().plot()
# Out:
# <AxesSubplot:title={'center':'Cummulative Total Profit - 2018-01*28'}, xlabel='Timestamp', ylabel='Cummulative Profit by Time'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** That there was one incredible arbitrage profit opportunity on the January day selected (1/28/2018); but as the difference narrowed it became a losing trade when factoring in trading costs regardless of which exchange is used for middle (2/15/2018) and late (3/28/2018).This is primarily driven by the fact the smaller average spread is not sufficient to cover trading costs. In conclusion if a trading strategy was set based on the large opportunity in January, the loses would have been signficant in Feb or March if trying to pursue an arbitrage opportunity because it narrowed and became non-existent as other traders most likely saw the large price dislocation in January as well.
